# %%
import pickle

from NESTED_CV_ import NESTED_CV

from sklearn.model_selection import RandomizedSearchCV

# %%
def run_NESTED_CV(name, CV):

  """
  Function that:
  - runs the NESTED_CV for a desired model in the class and for a given number of folds
  - default is 10-folds i.e., CV = None
  - prints status and progress of NESTED_CV
  - formats the results as a datafarme, and saves them locally
  - assigns the best HPs to the model, trains, and saves its locally
  - then returns the results dataframe and the saved model
  """
  if __name__ == '__main__':
    model_instance = NESTED_CV(model_type = name)
    model_instance.input_target()
    model_instance.cross_validation(CV)
    model_instance.results()
    model_instance.best_model()
    model_instance.CV_dataset.to_pickle("C:/chem papers/Dataset_17_feat.xlsx"+str(name)+".pkl", compression='infer', protocol=5, storage_options=None) # save dataframe as pickle file
    with open('Trained_models/17_feat_'+str(name)+'_model.pkl', 'wb') as file: # Save the Model to pickle file
          pickle.dump(model_instance.best_model, file)
    return model_instance.CV_dataset, model_instance.best_model

# %%
NESTED_CV()
# Out:
# #######################
# SELECTION UNAVAILABLE!
# #######################
#
# Please chose one of the following options:
#
#  'MLR'for multiple linear regression
#
#  'lasso' for multiple linear regression with east absolute shrinkage and selection operator (lasso)
#
#  'kNN'for k-Nearest Neighbors
#
#  'PLS' for partial least squares
#
#  'SVR' for support vertor regressor
#
#  'DT' for decision tree
#
#  'RF' for random forest
#
#  'LGBM' for LightGBM
#
#  'XGB' for XGBoost
#
#  'NGB' for NGBoost

# %%
MLR_result, MLR_model = run_NESTED_CV("MLR", None)
# Out:
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.233, Best_Valid_Score: 0.242,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.279, Best_Valid_Score: 0.230,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.253, Best_Valid_Score: 0.247,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.344, Best_Valid_Score: 0.276,
#
# Best_Model_Params:
# {'positive': True, 'fit_intercept': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.247, Best_Valid_Score: 0.231,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.218, Best_Valid_Score: 0.245,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.270, Best_Valid_Score: 0.244,
#
# Best_Model_Params:
# {'positive': True, 'fit_intercept': True}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.225, Best_Valid_Score: 0.249,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.240, Best_Valid_Score: 0.230,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.239, Best_Valid_Score: 0.249,
#
# Best_Model_Params:
# {'positive': False, 'fit_intercept': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(

# %%
lasso_result, lasso_model = run_NESTED_CV("lasso", None)
# Out:
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.261, Best_Valid_Score: 0.244,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.01}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.261, Best_Valid_Score: 0.250,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.02}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.257, Best_Valid_Score: 0.236,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.01}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.259, Best_Valid_Score: 0.236,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.02}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.253, Best_Valid_Score: 0.248,
#
# Best_Model_Params:
# {'positive': True, 'alpha': 0.01}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.256, Best_Valid_Score: 0.248,
#
# Best_Model_Params:
# {'positive': True, 'alpha': 0.02}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.232, Best_Valid_Score: 0.224,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.02}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.256, Best_Valid_Score: 0.246,
#
# Best_Model_Params:
# {'positive': True, 'alpha': 0.02}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.246, Best_Valid_Score: 0.243,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.01}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 14 is smaller than n_iter=100. Running 14 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.265, Best_Valid_Score: 0.243,
#
# Best_Model_Params:
# {'positive': False, 'alpha': 0.02}
#
# ################################################################

# %%
kNN_result, kNN_model = run_NESTED_CV("kNN", None)
# Out:
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.128, Best_Valid_Score: 0.185,
#
# Best_Model_Params:
# {'weights': 'distance', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 30, 'algorithm': 'kd_tree'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.138, Best_Valid_Score: 0.183,
#
# Best_Model_Params:
# {'weights': 'uniform', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 50, 'algorithm': 'ball_tree'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.156, Best_Valid_Score: 0.192,
#
# Best_Model_Params:
# {'weights': 'uniform', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 75, 'algorithm': 'ball_tree'}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.165, Best_Valid_Score: 0.173,
#
# Best_Model_Params:
# {'weights': 'distance', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 75, 'algorithm': 'brute'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.176, Best_Valid_Score: 0.182,
#
# Best_Model_Params:
# {'weights': 'uniform', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 75, 'algorithm': 'ball_tree'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.188, Best_Valid_Score: 0.180,
#
# Best_Model_Params:
# {'weights': 'distance', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 100, 'algorithm': 'auto'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.236, Best_Valid_Score: 0.155,
#
# Best_Model_Params:
# {'weights': 'distance', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 50, 'algorithm': 'ball_tree'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.159, Best_Valid_Score: 0.190,
#
# Best_Model_Params:
# {'weights': 'uniform', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 100, 'algorithm': 'ball_tree'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.232, Best_Valid_Score: 0.170,
#
# Best_Model_Params:
# {'weights': 'uniform', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 30, 'algorithm': 'auto'}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.186, Best_Valid_Score: 0.176,
#
# Best_Model_Params:
# {'weights': 'distance', 'p': 1, 'n_neighbors': 2, 'metric': 'minkowski', 'leaf_size': 75, 'algorithm': 'auto'}
#
# ################################################################

# %%
PLS_result, PLS_model = run_NESTED_CV("PLS", None)
# Out:
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.248, Best_Valid_Score: 0.248,
#
# Best_Model_Params:
# {'n_components': 4, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.222, Best_Valid_Score: 0.246,
#
# Best_Model_Params:
# {'n_components': 2, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.262, Best_Valid_Score: 0.237,
#
# Best_Model_Params:
# {'n_components': 4, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.335, Best_Valid_Score: 0.235,
#
# Best_Model_Params:
# {'n_components': 2, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.231, Best_Valid_Score: 0.242,
#
# Best_Model_Params:
# {'n_components': 2, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.219, Best_Valid_Score: 0.257,
#
# Best_Model_Params:
# {'n_components': 4, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.278, Best_Valid_Score: 0.224,
#
# Best_Model_Params:
# {'n_components': 2, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.219, Best_Valid_Score: 0.258,
#
# Best_Model_Params:
# {'n_components': 4, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.252, Best_Valid_Score: 0.258,
#
# Best_Model_Params:
# {'n_components': 4, 'max_iter': 250}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.253, Best_Valid_Score: 0.255,
#
# Best_Model_Params:
# {'n_components': 2, 'max_iter': 250}
#
# ################################################################

# %%
SVR_result, SVR_model = run_NESTED_CV("SVR", None)
# Out:
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.180, Best_Valid_Score: 0.207,
#
# Best_Model_Params:
# {'shrinking': True, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'degree': 6, 'C': 2}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.217, Best_Valid_Score: 0.199,
#
# Best_Model_Params:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'degree': 6, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.268, Best_Valid_Score: 0.198,
#
# Best_Model_Params:
# {'shrinking': True, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'degree': 5, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.209, Best_Valid_Score: 0.228,
#
# Best_Model_Params:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.001, 'degree': 2, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.161, Best_Valid_Score: 0.213,
#
# Best_Model_Params:
# {'shrinking': True, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'degree': 4, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.202, Best_Valid_Score: 0.219,
#
# Best_Model_Params:
# {'shrinking': True, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'degree': 2, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.221, Best_Valid_Score: 0.194,
#
# Best_Model_Params:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.15, 'degree': 5, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.226, Best_Valid_Score: 0.210,
#
# Best_Model_Params:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 'scale', 'epsilon': 0.2, 'degree': 3, 'C': 0.5}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.264, Best_Valid_Score: 0.198,
#
# Best_Model_Params:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.005, 'degree': 2, 'C': 0.1}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.463, Best_Valid_Score: 0.180,
#
# Best_Model_Params:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.05, 'degree': 3, 'C': 2}
#
# ################################################################

# %%
DT_result, DT_model = run_NESTED_CV("DT", None)
# Out:
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 230 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 58 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 172 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.29509557 -0.20107117 -0.29509557 -0.29509557         nan         nan
#  -0.20495486 -0.29509557 -0.29918371 -0.29918371         nan -0.29509557
#  -0.29509557 -0.1983973  -0.29509557 -0.29918371         nan -0.29918371
#  -0.19399275 -0.29918371         nan         nan         nan -0.18399371
#  -0.29509557 -0.29509557 -0.29509557 -0.29918371 -0.29509557 -0.29918371
#  -0.29918371         nan -0.29509557 -0.18285606 -0.29509557 -0.29918371
#  -0.29509557         nan         nan -0.29509557 -0.29509557         nan
#  -0.29509557 -0.1613921          nan -0.29918371 -0.22660346 -0.29509557
#          nan -0.29509557 -0.29509557 -0.22758186 -0.29509557 -0.29509557
#  -0.29918371 -0.23987191 -0.21858938 -0.29918371 -0.21776923 -0.29918371
#          nan -0.29918371         nan         nan -0.29509557         nan
#  -0.29509557 -0.29509557 -0.29509557 -0.29509557 -0.29509557         nan
#  -0.29509557 -0.29918371 -0.29509557 -0.18980306 -0.29509557         nan
#  -0.29509557 -0.18188263 -0.29918371 -0.29509557 -0.29918371 -0.20409518
#  -0.29509557 -0.29509557         nan -0.22758186 -0.29509557         nan
#  -0.29509557 -0.15593731 -0.29918371         nan -0.18758669         nan
#  -0.29509557 -0.29509557 -0.21858938 -0.29509557]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.139, Best_Valid_Score: 0.156,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'poisson', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 280 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 122 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 158 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.22388321 -0.29734314 -0.29734314 -0.21363385 -0.22287962 -0.29734314
#  -0.21386407 -0.29951156 -0.17838461 -0.1707559  -0.29734314 -0.29734314
#          nan -0.29734314 -0.29734314 -0.29734314         nan -0.29734314
#  -0.29734314         nan         nan -0.29734314         nan -0.17689567
#  -0.16215107 -0.29951156 -0.18580546 -0.29734314         nan         nan
#          nan         nan -0.29734314 -0.23317634 -0.29734314 -0.1860638
#          nan -0.29734314 -0.29734314 -0.2925166  -0.16714491         nan
#          nan         nan -0.29951156 -0.29734314         nan         nan
#  -0.29734314 -0.29734314         nan -0.14831103 -0.29734314 -0.29951156
#  -0.29734314 -0.29734314 -0.29734314 -0.29734314 -0.29734314 -0.17567204
#          nan -0.29734314 -0.29951156 -0.29734314         nan -0.29734314
#  -0.29734314 -0.1858413          nan         nan -0.29734314         nan
#  -0.29734314 -0.29734314 -0.16172432 -0.29734314 -0.29951156 -0.29951156
#  -0.16032965         nan -0.29951156 -0.29734314 -0.29734314 -0.16551536
#  -0.22287962         nan -0.17165463         nan -0.14831103         nan
#          nan -0.29734314 -0.29734314         nan -0.29734314         nan
#  -0.22388321 -0.29734314 -0.18658725 -0.29734314]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.152, Best_Valid_Score: 0.148,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 132 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 108 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.19431445 -0.29466777 -0.29466777 -0.29466777 -0.29466777 -0.1945646
#  -0.29466777 -0.22993839         nan -0.29466777 -0.30090854 -0.23501003
#          nan         nan -0.29466777 -0.30090854 -0.29466777 -0.29466777
#  -0.29466777 -0.1945646          nan -0.29466777 -0.29466777 -0.29466777
#  -0.30090854 -0.29466777 -0.29466777         nan         nan         nan
#          nan         nan -0.29466777 -0.29466777 -0.29466777 -0.16736105
#  -0.22579256         nan -0.29466777         nan -0.29466777 -0.20619344
#  -0.29466777         nan -0.30090854 -0.29466777 -0.29466777         nan
#  -0.29466777         nan         nan         nan -0.24275672 -0.1933001
#  -0.29466777         nan -0.2529653  -0.30090854 -0.29466777 -0.18083365
#  -0.21982371 -0.29466777         nan -0.29466777 -0.19073767 -0.29466777
#  -0.29466777 -0.29466777         nan -0.30090854 -0.17461291 -0.29466777
#          nan -0.29466777 -0.29466777 -0.29466777 -0.30090854 -0.30090854
#          nan -0.20958951 -0.23020543 -0.29466777 -0.29466777 -0.30090854
#  -0.30090854 -0.29466777 -0.24269874 -0.29466777 -0.29466777 -0.29466777
#  -0.29466777 -0.23020543 -0.29466777 -0.29466777         nan         nan
#  -0.29466777 -0.29466777 -0.30090854         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.173, Best_Valid_Score: 0.167,
#
# Best_Model_Params:
# {'splitter': 'random', 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 138 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 102 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.23023105 -0.30544368         nan         nan         nan         nan
#          nan -0.3089765  -0.30544368 -0.3089765  -0.3089765          nan
#  -0.30544368 -0.30544368         nan -0.30544368 -0.30544368 -0.25761571
#          nan -0.30544368         nan -0.22466974         nan         nan
#  -0.30544368 -0.30544368 -0.3089765  -0.30544368 -0.30544368 -0.30544368
#  -0.30544368 -0.30544368 -0.30544368 -0.30544368 -0.30544368 -0.17848875
#  -0.30544368 -0.30544368 -0.30544368 -0.30544368         nan -0.30544368
#  -0.24815509 -0.3089765  -0.30544368         nan         nan -0.30544368
#  -0.30544368 -0.19643833 -0.30544368 -0.30544368         nan         nan
#          nan -0.3089765  -0.1825446  -0.30544368 -0.31212048 -0.30544368
#          nan -0.30544368 -0.30544368 -0.30544368 -0.3089765  -0.30544368
#  -0.3089765  -0.30544368 -0.3089765  -0.30544368 -0.30544368 -0.3089765
#  -0.30544368 -0.30544368         nan -0.30544368 -0.3089765          nan
#  -0.30544368 -0.30544368 -0.30544368 -0.18510416 -0.3089765          nan
#          nan -0.15858575 -0.18271896         nan -0.30544368 -0.22618594
#  -0.30544368 -0.3089765  -0.30544368 -0.30544368 -0.30544368         nan
#  -0.18271384 -0.3089765  -0.17237049 -0.18637866]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.159, Best_Valid_Score: 0.159,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 180 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 92 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 88 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.21026387 -0.30581776 -0.30581776 -0.30581776 -0.30581776 -0.30581776
#          nan -0.21085362 -0.30581776         nan -0.30581776 -0.27427667
#  -0.15852175 -0.1737769  -0.30581776         nan -0.26452201         nan
#          nan -0.16808345 -0.30581776 -0.30907557 -0.30581776 -0.15657178
#  -0.15899579 -0.30581776         nan -0.17739369 -0.30581776 -0.30581776
#          nan -0.30907557 -0.30464494         nan         nan         nan
#  -0.17536274         nan         nan -0.18459446 -0.30907557 -0.30581776
#  -0.30581776 -0.30581776 -0.30907557 -0.30581776         nan -0.30907557
#  -0.30581776 -0.18784674 -0.16914012 -0.30581776 -0.30907557         nan
#  -0.30907557 -0.30907557 -0.15341134 -0.30581776 -0.30581776 -0.30581776
#  -0.30464494 -0.24024026 -0.30581776 -0.30581776 -0.30581776         nan
#  -0.30581776 -0.30581776 -0.30581776 -0.30581776 -0.30581776         nan
#          nan -0.30581776 -0.30907557 -0.30581776 -0.24024026 -0.30581776
#  -0.26017198 -0.30581776 -0.30581776 -0.30581776 -0.30581776 -0.21242986
#  -0.30907557         nan -0.30581776 -0.30581776 -0.30581776 -0.30581776
#  -0.30907557 -0.24024026 -0.30907557 -0.30581776 -0.30907557 -0.30907557
#  -0.30581776 -0.30581776 -0.15931288 -0.30907557]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.144, Best_Valid_Score: 0.153,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 320 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 152 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 168 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan         nan -0.18432926         nan -0.1782402  -0.22222364
#  -0.29965209         nan -0.21332066         nan -0.29965209 -0.29965209
#  -0.30573913         nan         nan -0.29965209 -0.18530001 -0.30573913
#  -0.29965209 -0.29965209 -0.29965209 -0.29965209         nan         nan
#          nan -0.2309383          nan -0.30573913 -0.22643073 -0.30573913
#  -0.1560294  -0.30573913 -0.19834814 -0.29965209 -0.19142116 -0.29965209
#  -0.29965209 -0.29965209 -0.30573913 -0.30573913 -0.30573913         nan
#  -0.17770292         nan         nan         nan         nan -0.17633935
#          nan         nan -0.21332066 -0.29965209 -0.20261841 -0.30573913
#  -0.29965209 -0.29965209 -0.15661857         nan -0.29965209 -0.30573913
#  -0.29965209 -0.29965209 -0.29965209 -0.29965209 -0.17421025         nan
#          nan         nan -0.30573913 -0.19062112 -0.17585739 -0.30573913
#          nan -0.29965209         nan         nan -0.29965209 -0.18432926
#  -0.29965209         nan -0.24263059 -0.29965209 -0.29965209 -0.15849287
#  -0.29965209 -0.29965209 -0.19250942         nan -0.30573913         nan
#  -0.16610586         nan -0.29965209 -0.24263059         nan -0.29965209
#  -0.30573913         nan -0.29965209         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.170, Best_Valid_Score: 0.156,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': None, 'criterion': 'poisson', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 140 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan -0.30346485 -0.30008638 -0.30008638         nan         nan
#  -0.30008638 -0.30346485         nan         nan -0.21721029 -0.30008638
#  -0.30008638         nan -0.30346485         nan -0.2150924  -0.30346485
#  -0.30008638 -0.30346485 -0.30008638 -0.19446868 -0.30008638 -0.30346485
#  -0.30008638 -0.30008638 -0.30008638 -0.16567298 -0.30008638 -0.30008638
#  -0.16483323 -0.30008638 -0.30008638 -0.2362657          nan -0.30008638
#  -0.30008638 -0.30008638 -0.30008638 -0.30346485 -0.17998694         nan
#  -0.30008638 -0.30346485 -0.30008638         nan -0.30346485 -0.30008638
#  -0.30008638         nan -0.18688821 -0.30008638         nan -0.30008638
#          nan -0.30008638 -0.30346485 -0.30008638 -0.30008638 -0.30008638
#  -0.30008638 -0.30008638 -0.15793899         nan         nan -0.30346485
#  -0.30346485 -0.30346485         nan         nan -0.30008638 -0.30008638
#  -0.16673686 -0.30008638         nan -0.30008638 -0.18784337 -0.19156361
#          nan -0.30008638         nan -0.30008638 -0.19446868 -0.30346485
#  -0.30008638 -0.30008638 -0.30008638 -0.17650265 -0.30008638         nan
#  -0.30008638         nan -0.30346485         nan -0.30346485 -0.20122246
#  -0.30008638         nan -0.30008638 -0.30008638]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.182, Best_Valid_Score: 0.158,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 260 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 132 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 128 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.29653139 -0.18491317 -0.29653139 -0.29653139 -0.29653139 -0.29653139
#  -0.29653139 -0.29653139         nan -0.29653139 -0.29653139 -0.29653139
#  -0.30171909 -0.29653139 -0.16211042 -0.25185309 -0.29653139 -0.30171909
#          nan -0.30171909 -0.18595917 -0.29653139 -0.29653139 -0.17725489
#  -0.29653139         nan -0.29653139 -0.29653139 -0.29653139         nan
#          nan         nan -0.30171909         nan -0.29653139 -0.29653139
#  -0.29653139 -0.1713212          nan -0.29653139 -0.29653139 -0.29653139
#          nan -0.17445292         nan -0.1713212  -0.30171909 -0.29653139
#  -0.29653139 -0.29653139 -0.30171909 -0.16628427 -0.30171909 -0.29653139
#  -0.29653139 -0.29653139         nan -0.18491317 -0.30171909         nan
#          nan -0.29653139 -0.29653139 -0.29653139 -0.21229708 -0.23883761
#          nan -0.29653139         nan         nan -0.29653139         nan
#  -0.2090626          nan -0.30171909 -0.17041166 -0.29653139         nan
#  -0.29653139 -0.29653139 -0.30171909         nan -0.22679879 -0.17560181
#  -0.16933078 -0.25185309 -0.30171909         nan -0.29653139         nan
#  -0.30171909         nan -0.30171909 -0.30171909 -0.18010489         nan
#          nan -0.29653139         nan -0.29653139]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.153, Best_Valid_Score: 0.162,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 220 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 102 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 118 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.30711262 -0.30711262         nan -0.30711262 -0.30764201 -0.30764201
#  -0.30711262 -0.30711262 -0.31348682 -0.30711262 -0.15074693 -0.30711262
#  -0.18297239 -0.16253538 -0.30711262 -0.31348682 -0.30711262 -0.30711262
#  -0.30711262         nan -0.30711262 -0.17598285 -0.23271135 -0.30711262
#          nan -0.31348682 -0.31348682         nan -0.30711262 -0.30711262
#  -0.30711262         nan         nan -0.31348682 -0.30711262 -0.22082476
#          nan         nan -0.23630347 -0.31348682         nan -0.31348682
#  -0.31348682         nan -0.25768568 -0.15516645 -0.30711262         nan
#  -0.22082476         nan -0.30711262         nan -0.31348682 -0.15294055
#  -0.30711262         nan -0.15270387 -0.30711262 -0.30711262 -0.31348682
#  -0.30711262         nan -0.30711262 -0.30711262 -0.30711262         nan
#  -0.30711262 -0.30711262 -0.15938836 -0.23271135 -0.30711262 -0.31348682
#  -0.30711262 -0.30711262         nan -0.30711262 -0.17317798 -0.30711262
#  -0.30711262 -0.30711262         nan -0.30711262 -0.30711262 -0.30711262
#  -0.18432518 -0.15172333 -0.20162596 -0.17975252 -0.31348682 -0.31348682
#  -0.31348682         nan -0.31348682 -0.31348682 -0.30711262         nan
#  -0.31348682 -0.30711262         nan         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.211, Best_Valid_Score: 0.151,
#
# Best_Model_Params:
# {'splitter': 'best', 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0}
#
# ################################################################
#
#
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.222, Best_Valid_Score: 0.156,
#
# Best_Model_Params:
# {'splitter': 'random', 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 125 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 115 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan -0.17892804 -0.29362724         nan -0.3000521  -0.1746851
#  -0.29362724 -0.17622041 -0.16370994 -0.3000521  -0.29362724 -0.29362724
#  -0.3000521  -0.1625784  -0.1587644  -0.29362724 -0.20836663 -0.3000521
#  -0.18408562 -0.1706106  -0.3000521  -0.16726373 -0.29362724 -0.19214833
#  -0.29362724         nan         nan -0.29362724         nan -0.18408562
#  -0.16033387         nan -0.29362724 -0.29362724 -0.29362724 -0.29362724
#  -0.29362724         nan -0.3000521  -0.3000521          nan -0.29362724
#          nan -0.29362724 -0.29362724 -0.19721794         nan -0.29362724
#          nan -0.29362724 -0.18992221 -0.16295207 -0.17667158         nan
#  -0.20434083         nan -0.29362724 -0.29362724         nan -0.29362724
#          nan -0.3000521  -0.17686134 -0.29362724 -0.29362724 -0.18728497
#  -0.29362724         nan         nan         nan -0.29362724 -0.3000521
#          nan -0.29362724 -0.29362724 -0.3000521  -0.18788587 -0.3000521
#  -0.19721794         nan -0.29362724 -0.29362724 -0.18512608 -0.29362724
#  -0.1571965  -0.16370994 -0.15620446 -0.16176106         nan -0.3000521
#          nan -0.29362724 -0.29362724 -0.29362724         nan -0.29362724
#  -0.29362724 -0.3000521  -0.21546312         nan]
#   warnings.warn(

# %%
RF_result, RF_model = run_NESTED_CV("RF", None)
# Out:
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 510 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 407 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 103 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan -0.23885097         nan
#          nan -0.14250881 -0.20483532         nan         nan         nan
#          nan -0.14360215 -0.23921661 -0.14520524 -0.21721209 -0.20366651
#  -0.13988771 -0.20483532 -0.20385386         nan         nan -0.14498382
#          nan         nan -0.23921661         nan -0.13938668 -0.2148591
#          nan -0.20483532 -0.142679   -0.24141802         nan         nan
#          nan -0.18683107 -0.24141802         nan -0.13930655         nan
#          nan         nan -0.23946958 -0.21458361         nan -0.18741177
#          nan -0.18903242 -0.14604833         nan -0.13988771         nan
#          nan -0.18924619 -0.18744606         nan -0.23919803 -0.14588475
#          nan -0.21737076 -0.14420931         nan         nan         nan
#  -0.1399484          nan         nan         nan -0.20222602         nan
#  -0.1389016  -0.21519878 -0.20474444         nan -0.1365747          nan
#  -0.21519878 -0.23948161         nan -0.20222602 -0.23879269         nan
#  -0.21644234 -0.2036534  -0.14445669         nan -0.2381422  -0.14604833
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.14352304         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.110, Best_Valid_Score: 0.137,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 100, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 4, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 520 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 190 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 330 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.21793293 -0.18580236         nan -0.18687366 -0.13793114 -0.13041843
#          nan         nan -0.13773222 -0.13095876 -0.13338287         nan
#  -0.18554543         nan         nan         nan         nan         nan
#          nan -0.21332516         nan -0.21826768         nan -0.24671479
#          nan -0.21771162         nan         nan -0.21676118 -0.21045656
#          nan -0.18715825         nan         nan         nan -0.24518153
#          nan         nan -0.24660339         nan         nan -0.20900083
#  -0.20997969 -0.13174953 -0.13684534         nan         nan         nan
#          nan         nan         nan -0.24507761         nan         nan
#          nan -0.18554543 -0.13801353         nan         nan         nan
#          nan         nan -0.13289052         nan -0.24796832         nan
#          nan -0.14103846 -0.20900083 -0.22303049 -0.20866417 -0.13180115
#  -0.21920521 -0.24727961 -0.22132604 -0.20918349         nan -0.2081053
#          nan         nan         nan         nan -0.1867065  -0.14103846
#  -0.20908985 -0.1321937  -0.24634005         nan         nan -0.13199958
#          nan         nan -0.20918349         nan         nan -0.13920874
#          nan -0.13174953 -0.22280265 -0.13180115]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.115, Best_Valid_Score: 0.130,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 300, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 540 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 104 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 436 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan -0.19796787 -0.25096759         nan         nan -0.25255122
#          nan -0.25174238         nan         nan -0.22754651         nan
#  -0.21598005         nan         nan -0.22754651         nan -0.22710405
#  -0.21649854 -0.13941748         nan         nan         nan         nan
#  -0.22673764 -0.13854357         nan -0.14006751         nan -0.21861849
#          nan         nan         nan -0.22734558         nan -0.22637017
#          nan         nan -0.13792073         nan         nan -0.14658762
#          nan         nan -0.22726672 -0.25316658 -0.22609668         nan
#          nan         nan         nan         nan -0.19751868         nan
#  -0.2173228  -0.13987362         nan -0.19643731         nan -0.22819307
#  -0.14882096 -0.14861187         nan         nan         nan -0.21597632
#  -0.21573893 -0.14216913         nan         nan         nan         nan
#          nan         nan -0.14216913 -0.14240821         nan         nan
#          nan -0.19814583         nan         nan -0.19782765 -0.14437085
#  -0.15034577 -0.25392056         nan -0.25150752 -0.14911914 -0.2173228
#          nan -0.25084539         nan         nan         nan         nan
#  -0.22830941 -0.2503485  -0.14821953 -0.21808964]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.094, Best_Valid_Score: 0.138,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 400, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 460 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 194 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 266 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan -0.18508363         nan -0.20288517         nan         nan
#          nan -0.22200316 -0.22440638 -0.15315901         nan -0.2226916
#  -0.14770505         nan -0.1843864          nan         nan         nan
#          nan -0.2446657  -0.15045211 -0.14561466 -0.22296044         nan
#  -0.20459978 -0.14959924 -0.22162342         nan         nan -0.22170397
#          nan         nan -0.22118958 -0.14550171 -0.14622242         nan
#          nan -0.24443571 -0.24724366 -0.22340251 -0.20483236 -0.15080231
#  -0.20531188 -0.15212025         nan -0.20537282 -0.18641756         nan
#          nan -0.14817598         nan         nan         nan -0.24527289
#  -0.22321106 -0.18506426         nan         nan -0.22173479 -0.14828623
#  -0.24723895 -0.14781824 -0.2226916          nan         nan -0.14484148
#          nan         nan -0.15315901         nan -0.1836067  -0.14787409
#  -0.18439829         nan         nan -0.20531188         nan         nan
#  -0.14744701         nan         nan         nan -0.15138106 -0.20531188
#          nan         nan         nan         nan         nan -0.20527943
#  -0.24723895 -0.1531806  -0.2433803          nan -0.20531188 -0.20472686
#          nan -0.14681307 -0.18547046         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.097, Best_Valid_Score: 0.145,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 100, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 2, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 580 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 352 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 228 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.18366282         nan         nan -0.2513191  -0.13328035         nan
#  -0.13526346         nan -0.18699087         nan         nan -0.25159484
#          nan         nan -0.13602196 -0.20804287         nan         nan
#          nan         nan -0.22450467 -0.13331968         nan         nan
#          nan         nan         nan -0.24947368 -0.25170219         nan
#          nan         nan -0.22184596         nan         nan         nan
#          nan         nan         nan -0.20743117         nan         nan
#          nan         nan         nan         nan -0.18267527         nan
#  -0.20877381 -0.21039881 -0.13627372 -0.2206738  -0.18366282         nan
#          nan         nan         nan         nan -0.13452908         nan
#          nan         nan -0.20732991 -0.22163771         nan -0.12776623
#  -0.18233635 -0.2514729          nan -0.1855735  -0.13513321         nan
#          nan -0.2244894  -0.25252847 -0.25025063         nan -0.25170219
#  -0.2081118          nan         nan         nan         nan -0.1855442
#          nan         nan -0.12911967         nan -0.12923077 -0.12976812
#          nan -0.12860842 -0.25115122 -0.18408707 -0.12849547         nan
#          nan -0.20847123         nan         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.120, Best_Valid_Score: 0.128,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 400, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 540 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 476 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 64 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.1415445          nan -0.21077005 -0.22005483         nan -0.21176988
#  -0.13760814 -0.21005923 -0.13646529 -0.19218799         nan         nan
#          nan         nan         nan         nan -0.2467716          nan
#          nan         nan         nan -0.22149418         nan         nan
#          nan -0.22032224         nan         nan -0.19093839 -0.2205071
#  -0.18899275 -0.21005923         nan -0.21008227         nan -0.14497255
#          nan         nan -0.19008775         nan -0.24876823         nan
#  -0.1903089  -0.13806152         nan -0.14512063 -0.1474397          nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan -0.22082324 -0.24728308 -0.20904786
#  -0.14339531         nan -0.13872261         nan -0.24720691         nan
#          nan         nan -0.14595159 -0.2205071  -0.21872985         nan
#          nan -0.21956969         nan -0.14497104         nan         nan
#  -0.24844926 -0.1412427  -0.22002305 -0.22033356         nan         nan
#          nan -0.1355888          nan -0.13227527         nan -0.22033356
#  -0.18970245 -0.1336172          nan -0.2093402          nan -0.20962039
#          nan         nan         nan -0.14475547]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.133, Best_Valid_Score: 0.132,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 100, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 580 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 376 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 204 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan -0.19468567         nan         nan
#  -0.1273228          nan         nan -0.23437573         nan -0.19572072
#  -0.12950239         nan         nan         nan         nan -0.23508474
#          nan -0.17433416         nan -0.1740108  -0.1341001          nan
#          nan -0.23593704         nan -0.23474733         nan -0.23577679
#          nan         nan         nan         nan -0.17226275 -0.19626982
#          nan -0.12606795         nan         nan -0.19323482 -0.17283868
#          nan         nan -0.21415075 -0.23806074         nan         nan
#          nan         nan -0.21321513         nan -0.13655608         nan
#          nan         nan -0.13325149         nan -0.23723038 -0.13661171
#  -0.19571922 -0.21431002         nan -0.1944106          nan -0.19434418
#          nan -0.23474733         nan -0.17426666 -0.19499668         nan
#  -0.13469173 -0.13782602         nan         nan         nan         nan
#          nan         nan -0.19428283 -0.12400426         nan -0.13655608
#  -0.21595128         nan -0.23527217         nan         nan         nan
#          nan -0.17394726 -0.13447068 -0.1331921          nan         nan
#          nan         nan -0.19538603         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.113, Best_Valid_Score: 0.124,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 400, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 500 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 420 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan         nan -0.24596668         nan         nan         nan
#          nan -0.19228177 -0.13816812 -0.22056716 -0.13778659 -0.13951942
#  -0.21961677         nan         nan         nan         nan         nan
#          nan -0.13931821         nan         nan -0.19362913 -0.13692522
#  -0.14750531 -0.24316204         nan         nan         nan         nan
#          nan         nan         nan         nan -0.13778659         nan
#  -0.14343314         nan -0.20914693         nan -0.20921932         nan
#          nan -0.21168246         nan         nan -0.21968029 -0.21991113
#          nan -0.14530507         nan         nan         nan -0.14046426
#  -0.19139864         nan -0.19174227         nan -0.24206809 -0.21991113
#          nan -0.14486714         nan -0.24268707 -0.14130734 -0.24402629
#          nan -0.13945487         nan         nan         nan -0.21014568
#  -0.22139422 -0.24425117         nan -0.24268707 -0.1460928  -0.21141082
#          nan -0.19184283 -0.24324745 -0.14149279         nan -0.19170511
#          nan -0.21002979 -0.13834875 -0.13771053         nan -0.19174227
#  -0.21372774 -0.22066998 -0.21168246         nan         nan -0.14343422
#  -0.24280014         nan -0.19362913         nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.107, Best_Valid_Score: 0.137,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 100, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 490 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 378 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 112 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-0.21598395         nan         nan -0.19765222 -0.21743194 -0.21496902
#          nan         nan -0.19765222 -0.19488652         nan -0.1744493
#          nan -0.17547069 -0.12368686 -0.1963635  -0.19647283 -0.17503005
#  -0.12620945         nan         nan -0.13028293         nan         nan
#  -0.24412918         nan -0.1966149          nan -0.12615443         nan
#  -0.17458882 -0.19673307         nan         nan         nan         nan
#  -0.24113006         nan -0.24256658 -0.127817   -0.13023363         nan
#          nan         nan -0.24113006         nan -0.13149835 -0.13075186
#  -0.24131876         nan         nan         nan         nan         nan
#          nan         nan -0.12952394 -0.12408354 -0.17684626 -0.19549075
#          nan -0.17486467 -0.12408354         nan -0.12868282         nan
#          nan         nan -0.17602824         nan         nan -0.17700461
#          nan         nan -0.12991669 -0.19673307         nan         nan
#  -0.1963635  -0.21400052         nan         nan -0.24129588 -0.19683953
#  -0.19631173 -0.19816295         nan -0.24105965         nan         nan
#          nan -0.24286134 -0.21454213 -0.2405063  -0.19765222 -0.19532279
#          nan         nan -0.1313396          nan]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.143, Best_Valid_Score: 0.124,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 300, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 4, 'min_samples_leaf': 2, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 550 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 373 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 177 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [        nan         nan -0.12833332         nan -0.2140955          nan
#          nan -0.13018531         nan -0.13044318 -0.18621754 -0.12723995
#          nan         nan         nan         nan         nan -0.24130904
#  -0.24185059         nan         nan -0.18463502         nan         nan
#  -0.13076449         nan -0.21520565 -0.18507023 -0.12933129 -0.24133487
#  -0.18499022         nan -0.24163956 -0.24130314 -0.1273234  -0.13550795
#          nan -0.21545975 -0.13227581         nan         nan -0.21535959
#  -0.12727211         nan -0.21583401         nan -0.18506954         nan
#          nan -0.13389348 -0.24260248         nan -0.18595978 -0.138417
#          nan         nan         nan         nan -0.20631119         nan
#          nan -0.24143491         nan -0.20254953         nan -0.24185059
#  -0.21575489         nan -0.18487044         nan -0.24228629         nan
#          nan         nan         nan         nan         nan         nan
#          nan -0.13550795         nan         nan -0.20554546         nan
#  -0.13292558 -0.13684906         nan         nan         nan         nan
#  -0.21732058         nan         nan -0.18463502 -0.20505217 -0.12949569
#          nan         nan         nan -0.18733076]
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.136, Best_Valid_Score: 0.127,
#
# Best_Model_Params:
# {'oob_score': True, 'n_estimators': 100, 'min_weight_fraction_leaf': 0.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0, 'bootstrap': True}
#
# ################################################################

# %%
LGBM_result, LGBM_model = run_NESTED_CV("LGBM", None)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1214
# [LightGBM] [Info] Number of data points in the train set: 3463, number of used features: 17
# [LightGBM] [Info] Start training from score 0.476951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.099, Best_Valid_Score: 0.131,
#
# Best_Model_Params:
# {'subsample': 0.6, 'reg_lambda': 0, 'reg_alpha': 0, 'num_leaves': 128, 'n_estimators': 200, 'min_child_weight': 0.01, 'min_child_samples': 100, 'learning_rate': 0.1, 'boosting_type': 'gbdt'}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000660 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1130
# [LightGBM] [Info] Number of data points in the train set: 3237, number of used features: 17
# [LightGBM] [Info] Start training from score 0.489486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.124, Best_Valid_Score: 0.127,
#
# Best_Model_Params:
# {'subsample': 0.4, 'reg_lambda': 0, 'reg_alpha': 0, 'num_leaves': 128, 'n_estimators': 300, 'min_child_weight': 10.0, 'min_child_samples': 100, 'learning_rate': 0.1, 'boosting_type': 'dart'}
#
# ################################################################
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000458 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1071
# [LightGBM] [Info] Number of data points in the train set: 3077, number of used features: 17
# [LightGBM] [Info] Start training from score 0.464781
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.103, Best_Valid_Score: 0.118,
#
# Best_Model_Params:
# {'subsample': 1.0, 'reg_lambda': 0.015, 'reg_alpha': 0.01, 'num_leaves': 16, 'n_estimators': 500, 'min_child_weight': 0.001, 'min_child_samples': 100, 'learning_rate': 0.1, 'boosting_type': 'dart'}
#
# ################################################################
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1095
# [LightGBM] [Info] Number of data points in the train set: 2385, number of used features: 17
# [LightGBM] [Info] Start training from score 0.455148
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.101, Best_Valid_Score: 0.129,
#
# Best_Model_Params:
# {'subsample': 1.0, 'reg_lambda': 0, 'reg_alpha': 0, 'num_leaves': 16, 'n_estimators': 300, 'min_child_weight': 1.0, 'min_child_samples': 10, 'learning_rate': 0.1, 'boosting_type': 'dart'}
#
# ################################################################
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000430 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1090
# [LightGBM] [Info] Number of data points in the train set: 3119, number of used features: 17
# [LightGBM] [Info] Start training from score 0.477362
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.113, Best_Valid_Score: 0.122,
#
# Best_Model_Params:
# {'subsample': 0.6, 'reg_lambda': 0.015, 'reg_alpha': 0.01, 'num_leaves': 16, 'n_estimators': 600, 'min_child_weight': 1.0, 'min_child_samples': 10, 'learning_rate': 0.1, 'boosting_type': 'dart'}
#
# ################################################################
#
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1173
# [LightGBM] [Info] Number of data points in the train set: 3097, number of used features: 17
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 0.471320
# C:\Users\prajw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
#
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.126, Best_Valid_Score: 0.129,
#
# Best_Model_Params:
# {'subsample': 0.8, 'reg_lambda': 0, 'reg_alpha': 0.015, 'num_leaves': 128, 'n_estimators': 150, 'min_child_weight': 0.01, 'min_child_samples': 2, 'learning_rate': 0.1, 'boosting_type': 'goss'}
#
# ################################################################
#
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000420 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1039
# [LightGBM] [Info] Number of data points in the train set: 2171, number of used features: 17
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 0.434580
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
NGB_result, NGB_model = run_NESTED_CV("NGB", None)
# Out:
# [iter 0] loss=0.2845 val_loss=0.0000 scale=2.0000 norm=0.9715
# [iter 100] loss=-0.8229 val_loss=0.0000 scale=2.0000 norm=0.9001
# [iter 200] loss=-1.8480 val_loss=0.0000 scale=2.0000 norm=0.9589
# [iter 300] loss=-2.9628 val_loss=0.0000 scale=2.0000 norm=0.9891
# [iter 400] loss=-4.8033 val_loss=0.0000 scale=4.0000 norm=1.9963
# [iter 500] loss=-6.9604 val_loss=0.0000 scale=4.0000 norm=1.9972
#
# ################################################################
#
# STATUS REPORT:
# Iteration 1 of 10 runs completed
# Test_Score: 0.089, Best_Valid_Score: 0.129,
#
# Best_Model_Params:
# {'n_estimators': 600, 'minibatch_frac': 0.8, 'learning_rate': 0.01, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=16)}
#
# ################################################################
#
# [iter 0] loss=0.2925 val_loss=0.0000 scale=1.0000 norm=0.4922
# [iter 100] loss=-3.4249 val_loss=0.0000 scale=1.0000 norm=0.3560
# [iter 200] loss=-3.9365 val_loss=0.0000 scale=1.0000 norm=0.3128
# [iter 300] loss=-4.3191 val_loss=0.0000 scale=1.0000 norm=0.2974
# [iter 400] loss=-4.6470 val_loss=0.0000 scale=0.5000 norm=0.1507
# [iter 500] loss=-4.9738 val_loss=0.0000 scale=1.0000 norm=0.2880
# [iter 600] loss=-5.2342 val_loss=0.0000 scale=0.5000 norm=0.1430
# [iter 700] loss=-5.5568 val_loss=0.0000 scale=0.5000 norm=0.1424
#
# ################################################################
#
# STATUS REPORT:
# Iteration 2 of 10 runs completed
# Test_Score: 0.130, Best_Valid_Score: 0.125,
#
# Best_Model_Params:
# {'n_estimators': 800, 'minibatch_frac': 0.5, 'learning_rate': 0.1, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=8)}
#
# ################################################################
#
# [iter 0] loss=0.2754 val_loss=0.0000 scale=2.0000 norm=0.9691
# [iter 100] loss=-0.8184 val_loss=0.0000 scale=2.0000 norm=0.8917
# [iter 200] loss=-1.8008 val_loss=0.0000 scale=2.0000 norm=0.9582
# [iter 300] loss=-2.8935 val_loss=0.0000 scale=4.0000 norm=1.9501
# [iter 400] loss=-4.0711 val_loss=0.0000 scale=4.0000 norm=1.8956
#
# ################################################################
#
# STATUS REPORT:
# Iteration 3 of 10 runs completed
# Test_Score: 0.097, Best_Valid_Score: 0.129,
#
# Best_Model_Params:
# {'n_estimators': 500, 'minibatch_frac': 0.5, 'learning_rate': 0.01, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=16)}
#
# ################################################################
#
# [iter 0] loss=0.3418 val_loss=0.0000 scale=2.0000 norm=0.9807
# [iter 100] loss=-3.0010 val_loss=0.0000 scale=1.0000 norm=0.3885
# [iter 200] loss=-3.6601 val_loss=0.0000 scale=1.0000 norm=0.3472
# [iter 300] loss=-4.0327 val_loss=0.0000 scale=1.0000 norm=0.2766
#
# ################################################################
#
# STATUS REPORT:
# Iteration 4 of 10 runs completed
# Test_Score: 0.153, Best_Valid_Score: 0.130,
#
# Best_Model_Params:
# {'n_estimators': 400, 'minibatch_frac': 1.0, 'learning_rate': 0.1, 'col_sample': 0.5, 'Base': DecisionTreeRegressor(max_depth=8)}
#
# ################################################################
#
# [iter 0] loss=0.3222 val_loss=0.0000 scale=1.0000 norm=0.4928
# [iter 100] loss=-0.4253 val_loss=0.0000 scale=2.0000 norm=0.7879
# [iter 200] loss=-1.0426 val_loss=0.0000 scale=2.0000 norm=0.7849
# [iter 300] loss=-1.3775 val_loss=0.0000 scale=1.0000 norm=0.3897
#
# ################################################################
#
# STATUS REPORT:
# Iteration 5 of 10 runs completed
# Test_Score: 0.117, Best_Valid_Score: 0.123,
#
# Best_Model_Params:
# {'n_estimators': 400, 'minibatch_frac': 0.5, 'learning_rate': 0.01, 'col_sample': 1, 'Base': DecisionTreeRegressor(max_depth=4)}
#
# ################################################################
#
# [iter 0] loss=0.2883 val_loss=0.0000 scale=2.0000 norm=0.9679
# [iter 100] loss=-3.4720 val_loss=0.0000 scale=1.0000 norm=0.3391
# [iter 200] loss=-3.9647 val_loss=0.0000 scale=1.0000 norm=0.3246
#
# ################################################################
#
# STATUS REPORT:
# Iteration 6 of 10 runs completed
# Test_Score: 0.122, Best_Valid_Score: 0.126,
#
# Best_Model_Params:
# {'n_estimators': 300, 'minibatch_frac': 0.5, 'learning_rate': 0.1, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=8)}
#
# ################################################################
#
# [iter 0] loss=0.3356 val_loss=0.0000 scale=1.0000 norm=0.4972
# [iter 100] loss=-0.7782 val_loss=0.0000 scale=2.0000 norm=0.9108
# [iter 200] loss=-1.7291 val_loss=0.0000 scale=2.0000 norm=0.9435
# [iter 300] loss=-2.6058 val_loss=0.0000 scale=2.0000 norm=0.8775
# [iter 400] loss=-3.3118 val_loss=0.0000 scale=2.0000 norm=0.7528
# [iter 500] loss=-3.7745 val_loss=0.0000 scale=2.0000 norm=0.6763
# [iter 600] loss=-3.9216 val_loss=0.0000 scale=1.0000 norm=0.3279
# [iter 700] loss=-4.0497 val_loss=0.0000 scale=1.0000 norm=0.3234
#
# ################################################################
#
# STATUS REPORT:
# Iteration 7 of 10 runs completed
# Test_Score: 0.138, Best_Valid_Score: 0.119,
#
# Best_Model_Params:
# {'n_estimators': 800, 'minibatch_frac': 0.5, 'learning_rate': 0.01, 'col_sample': 1, 'Base': DecisionTreeRegressor(max_depth=8)}
#
# ################################################################
#
# [iter 0] loss=0.2855 val_loss=0.0000 scale=2.0000 norm=0.9799
# [iter 100] loss=-0.8377 val_loss=0.0000 scale=2.0000 norm=0.9036
# [iter 200] loss=-1.8166 val_loss=0.0000 scale=2.0000 norm=0.9678
# [iter 300] loss=-3.0178 val_loss=0.0000 scale=2.0000 norm=0.9639
# [iter 400] loss=-4.1315 val_loss=0.0000 scale=2.0000 norm=0.9332
#
# ################################################################
#
# STATUS REPORT:
# Iteration 8 of 10 runs completed
# Test_Score: 0.110, Best_Valid_Score: 0.133,
#
# Best_Model_Params:
# {'n_estimators': 500, 'minibatch_frac': 0.5, 'learning_rate': 0.01, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=16)}
#
# ################################################################
#
# [iter 0] loss=0.3085 val_loss=0.0000 scale=2.0000 norm=0.9652
# [iter 100] loss=-0.7670 val_loss=0.0000 scale=2.0000 norm=0.8891
# [iter 200] loss=-1.7801 val_loss=0.0000 scale=2.0000 norm=0.9707
# [iter 300] loss=-2.9091 val_loss=0.0000 scale=2.0000 norm=0.9910
# [iter 400] loss=-4.6934 val_loss=0.0000 scale=4.0000 norm=1.9955
# [iter 500] loss=-6.6912 val_loss=0.0000 scale=4.0000 norm=1.9968
# [iter 600] loss=-8.6847 val_loss=0.0000 scale=4.0000 norm=1.9911
# [iter 700] loss=-10.5420 val_loss=0.0000 scale=2.0000 norm=0.9737
#
# ################################################################
#
# STATUS REPORT:
# Iteration 9 of 10 runs completed
# Test_Score: 0.151, Best_Valid_Score: 0.124,
#
# Best_Model_Params:
# {'n_estimators': 800, 'minibatch_frac': 0.8, 'learning_rate': 0.01, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=16)}
#
# ################################################################
#
# [iter 0] loss=0.2643 val_loss=0.0000 scale=1.0000 norm=0.4805
# [iter 100] loss=-0.2404 val_loss=0.0000 scale=1.0000 norm=0.3733
# [iter 200] loss=-0.7526 val_loss=0.0000 scale=2.0000 norm=0.7476
#
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.150, Best_Valid_Score: 0.120,
#
# Best_Model_Params:
# {'n_estimators': 300, 'minibatch_frac': 0.5, 'learning_rate': 0.01, 'col_sample': 0.8, 'Base': DecisionTreeRegressor(max_depth=4)}
#
# ################################################################
#
# [iter 0] loss=0.3155 val_loss=0.0000 scale=1.0000 norm=0.4843
# [iter 100] loss=-3.3777 val_loss=0.0000 scale=0.5000 norm=0.1735
# [iter 200] loss=-3.8391 val_loss=0.0000 scale=1.0000 norm=0.3225
